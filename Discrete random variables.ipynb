# %%
from numpy.random import choice

# %%
choice([1, 2, 4], p=[0.2, 0.5, 0.3])
# Out:
# 4

# %%
def count_frequencies(data, relative=False):
    counter = {}
    for element in data:
        if element not in counter:
            # first encounter with this data
            counter[element] = 1
        else:
            counter[element] = counter[element] + 1
    if relative:
        for element in counter:
            counter[element] = counter[element] / len(data)
    return counter

# %%
count_frequencies([1, 1, 2, 1])
# Out:
# {1: 3, 2: 1}

# %%
count_frequencies([1, 1, 2, 1], relative=True)
# Out:
# {1: 0.75, 2: 0.25}

# %%
sample = [choice([1, 2, 4], p=[0.2, 0.5, 0.3])
         for _ in range(100000)]

# %%
sample
# Out:
# [1,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  1,
#  2,
#  1,
#  4,
#  2,
#  2,
#  2,
#  1,
#  1,
#  2,
#  4,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  1,
#  4,
#  4,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  4,
#  4,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  4,
#  4,
#  1,
#  2,
#  4,
#  4,
#  1,
#  2,
#  2,
#  4,
#  1,
#  2,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  1,
#  1,
#  1,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  1,
#  2,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  1,
#  2,
#  2,
#  1,
#  2,
#  4,
#  1,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  2,
#  4,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  2,
#  4,
#  2,
#  2,
#  2,
#  1,
#  4,
#  2,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  2,
#  1,
#  1,
#  2,
#  4,
#  4,
#  2,
#  2,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  4,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  4,
#  1,
#  1,
#  4,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  1,
#  4,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  1,
#  1,
#  2,
#  1,
#  4,
#  1,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  2,
#  1,
#  4,
#  4,
#  2,
#  2,
#  1,
#  4,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  4,
#  2,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  1,
#  4,
#  1,
#  4,
#  1,
#  4,
#  1,
#  1,
#  1,
#  4,
#  2,
#  4,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  4,
#  1,
#  1,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  2,
#  4,
#  4,
#  1,
#  4,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  4,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  1,
#  4,
#  4,
#  1,
#  1,
#  4,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  4,
#  2,
#  4,
#  4,
#  1,
#  2,
#  4,
#  2,
#  1,
#  1,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  4,
#  4,
#  1,
#  4,
#  1,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  4,
#  1,
#  2,
#  1,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  4,
#  2,
#  2,
#  2,
#  1,
#  4,
#  1,
#  1,
#  1,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  1,
#  4,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  1,
#  4,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  4,
#  1,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  1,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  1,
#  1,
#  4,
#  2,
#  2,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  1,
#  4,
#  2,
#  2,
#  1,
#  1,
#  4,
#  2,
#  2,
#  4,
#  1,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  1,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  1,
#  2,
#  1,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  1,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  1,
#  4,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  1,
#  4,
#  1,
#  2,
#  2,
#  4,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  4,
#  4,
#  1,
#  1,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  1,
#  4,
#  4,
#  2,
#  4,
#  1,
#  2,
#  1,
#  1,
#  4,
#  2,
#  4,
#  2,
#  4,
#  1,
#  2,
#  1,
#  1,
#  4,
#  4,
#  2,
#  4,
#  1,
#  4,
#  2,
#  2,
#  2,
#  1,
#  1,
#  2,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  1,
#  2,
#  2,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  4,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  2,
#  1,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  2,
#  1,
#  1,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  2,
#  1,
#  4,
#  4,
#  4,
#  1,
#  2,
#  4,
#  4,
#  2,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  1,
#  4,
#  1,
#  4,
#  1,
#  4,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  ...]

# %%
count_frequencies(sample, relative=True)
# Out:
# {1: 0.20008, 4: 0.30011, 2: 0.49981}

# %%
sample = choice([1, 2, 4], size=10000, p=[0.2, 0.5, 0.3])

# %% [markdown]
# sample

# %%
sample
# Out:
# array([4, 2, 2, ..., 2, 2, 4])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
freqs = count_frequencies(sample, relative=True)

# %%
plt.bar(list(freqs.keys()), list(freqs.values()))
# Out:
# <BarContainer object of 3 artists>
